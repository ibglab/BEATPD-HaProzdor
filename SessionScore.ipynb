# %% [markdown]
# # Session score
# Generate a single score for the session based on the different segment scores

# %%
import logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(asctime)s: %(message)s')

import warnings
warnings.filterwarnings('ignore')

import os
import numpy as np
import pandas as pd
from multiprocessing import Pool

from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_classif, SelectFromModel, f_regression
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

import imblearn
import getpass

import ClassificationUtils as helpFunc

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Set scoring parameters

# %%
def runClassification(train, test, labelName, useFirstHalf, selectFeatures, fixClassImbalance = 'none', seed=np.nan, regressionModel = False):
    #use only first half of session

    if useFirstHalf:
        train = helpFunc.cutSession(train)
        test = helpFunc.cutSession(test)

    train, _ = helpFunc.splitData(train, labelName=labelName, testSize=testSize, seed=seed)
    # remove Nans
    train = train.dropna(subset=[labelName])

    # Get X and y (train and test ) and labels
    # reassign indexes of train and test  (which changed after manipulations) to match simple range
    train.index = range(len(train))
    test.index = range(len(test))

    X_train = train.drop(['sessionID'] + y_fields, axis=1)
    y_train = train[labelName]
    X_test = test.drop(['sessionID'], axis=1)


    # Normalization
    min_max_scaler = preprocessing.MinMaxScaler(feature_range = (-1,1))
    min_max_scaler.fit(pd.concat([X_train, X_test], ignore_index=True))    
    X_train= min_max_scaler.transform(X_train)
    X_test= min_max_scaler.transform(X_test)

    # feature selection
    selFeat = selectFeatures.fit(X_train, y_train)
    # apply feature selection
    X_train = selFeat.transform(X_train)
    X_test = selFeat.transform(X_test)

    # handle class imbalance
    if fixClassImbalance != 'none':
        if fixClassImbalance=='SMOTEENN':
            smote_enn = imblearn.combine.SMOTEENN(random_state=0)
            X_train, y_train = smote_enn.fit_resample(X_train, y_train)
        elif fixClassImbalance == 'RandomUnderSampler':
            rus = imblearn.under_sampling.RandomUnderSampler(random_state=42)
            X_train, y_train = rus.fit_resample(X_train, y_train)

    # run models
    if regressionModel:
        clf = RandomForestRegressor(random_state = seed)
    else:
        clf = RandomForestClassifier(random_state = seed)
    clf.fit(X_train, y_train)

    all_y_pred = clf.predict(X_test)

    sessionIDs = test['sessionID'].unique()
    y_pred = np.zeros(len(sessionIDs))

    for i, sessionID in enumerate(sessionIDs):
        sessionIdx = test.index[test['sessionID']==sessionID].tolist()
        y_pred[i] = all_y_pred[sessionIdx].astype(np.intp).mean()

    d = {'sessionID': sessionIDs, 'y_pred': y_pred}
    y_predictions = pd.DataFrame(data=d)

    return sessionIDs, y_pred

# %%
def SessionScoreSeed(seed):
    all_results, all_pred = {}, {}
    # load tables
    for i, labelName in enumerate(y_fields):

        resFile = os.path.join('features_seeds_summary', dataset.lower(), test_rand, labelName+'_allResults_seed'+str(seed)+'.csv')
        if dataset == 'cis':
            predFile = os.path.join('features', 'BEAT-PD_SC' + str(i+1) + '_'+labelName +'_'+test_rand+'.csv')
        else:
            predFile = os.path.join(outputFolder, 'BEAT-PD_SC' + str(i+1) + '_'+labelName +'_'+ str(seed) + '.csv')
        
        logging.info(f'Seed {seed} Score {labelName}: Input {resFile} Output {predFile}')
        dfRes = pd.read_csv(resFile)
        dfRes = dfRes.set_index(list(dfRes.columns[[0]]))
        dfPred = pd.read_csv(predFile)
        
        all_results[labelName] = dfRes
        all_pred[labelName]= dfPred

    for id in subject_ids:
        subjectTrainFolderName = dataSetFolderName + str(id)
        subjectTestFolderName = dataSetFolderName + str(id) + '_test'
        
        train = pd.read_csv(os.path.join(subjectTrainFolderName, feature_file), delim_whitespace=True, header=None, mangle_dupe_cols=True)
        test = pd.read_csv(os.path.join(subjectTestFolderName, feature_file), delim_whitespace=True, header=None, mangle_dupe_cols=True)
        # add session number column to the dataframe
        train['sessionID'] = pd.read_csv(os.path.join(subjectTrainFolderName ,'sessionIDs.txt'), header=None, squeeze=True)
        test['sessionID'] = pd.read_csv(os.path.join(subjectTestFolderName ,'sessionIDs.txt'), header=None, squeeze=True)
        # add labels
        for y in y_fields:
            y_data = pd.read_csv(os.path.join(subjectTrainFolderName, 'y_'+ y + '.txt'), names=[y], squeeze=True)
            train[y] = y_data
            

        for labelName in y_fields:
            # if all values for the current labels are Nans, continue
            if train[labelName].isnull().all():
                continue

            dfRes = all_results[labelName].loc[id]

            dfPred = all_pred[labelName]

            bestField = dfRes.index[dfRes.argmin()]
 
            logging.info(f'Seed {seed} Subject {id} Score {labelName} Best method {bestField}')

            if bestField == labelName + '_useWholeS':
                useFirstHalf = False
            else: 
                useFirstHalf = True
                
            if bestField == labelName + '_RFregressor':
                regressionModel = True
            else:
                regressionModel = False
            
            if bestField == labelName + '_kBest50':
                selectFeatures = SelectKBest(score_func=f_classif, k=50)
            elif bestField == labelName + '_rfFeatueSel':
                selectFeatures = SelectFromModel(RandomForestClassifier(random_state = seed))
            elif bestField == labelName + '_RFregressor':
                selectFeatures = SelectKBest(score_func=f_regression, k=selectKbest)
            else:
                selectFeatures = SelectKBest(score_func=f_classif, k=selectKbest)
                

            if bestField == labelName + '_undersample':
                fixClassImbalance = 'RandomUnderSampler'
            else:
                fixClassImbalance = 'none'
                
            if bestField == labelName + '_bestCombination':
                mseNaive = dfRes[labelName+'_naive']
                mseBase = dfRes[labelName+'_base']
                mseUseWholeS = dfRes[labelName+'_useWholeS']
                mseKbest50 = dfRes[labelName+'_kBest50']
                mseRfFeatueSel = dfRes[labelName+'_rfFeatureSel']
                mseUndersample = dfRes[labelName+'_undersample']
                mseBestComp = dfRes[labelName+'_bestCombination']
                
                if (mseBase < mseUseWholeS):
                    useFirstHalf = True
                else:
                    useFirstHalf = False
            
                minSelFeatScore = min(mseBase, mseKbest50, mseRfFeatueSel)
                if minSelFeatScore == mseBase:
                    selectFeatures = SelectKBest(score_func=f_classif, k=selectKbest)  #default
                elif minSelFeatScore == mseKbest50:
                    selectFeatures = SelectKBest(score_func=f_classif, k=50)
                elif minSelFeatScore == mseRfFeatueSel:
                    selectFeatures = SelectFromModel(RandomForestClassifier(random_state = seed))
            
                minClassBalScore = min(mseBase, mseUndersample)
                if minClassBalScore == mseBase:
                    fixClassImbalance = 'none'
                elif minClassBalScore == mseUndersample:
                    fixClassImbalance = 'RandomUnderSampler'    
                

            sessionIDs, y_pred = runClassification(train, test, labelName, useFirstHalf, selectFeatures, fixClassImbalance = fixClassImbalance, seed=seed)
            # update submission tables with the predictions
            for i, sessionID in enumerate(sessionIDs):
                sessionID = sessionID.replace(" ","")
                idx = dfPred[dfPred['measurement_id'] == sessionID ].index.tolist()
                if len(idx)==0:
                    logging.info('session not found in pred matrix' + sessionID)
                    continue
                dfPred.at[idx[0],'prediction'] = y_pred[i]

    # save
    for i, labelName in enumerate(y_fields):
        fileName = 'BEAT-PD_SC' + str(i+1) + '_'+ labelName + '_'+ str(seed) +'.csv'
        logging.info(f'Save file: {fileName}')
        dfPred = all_pred[labelName]
        dfPred = dfPred.set_index(list(dfPred.columns[[0]]))
        dfPred.to_csv(os.path.join(outputFolder, fileName))

# %% [markdown]
# ### Set parameters

# %%
datasets = ['cis', 'real']
test_rand = 'Submit_Final'
dataSetFolderName = os.path.join('pre_process', 'SegmentedData_winLen500_overlap250_')
selectKbest = 100
testSize = 0.2
y_fields = ['on_off', 'dyskinesia', 'tremor']

feature_file = 'X_data_fullFeatures.txt'

parallel = True        # Parallel (True) or serial (False) seed procesing
nworkers = 10          # Number of parallel workers
seeds = range(21,33)

# %%
outputFolder = os.path.join('features', test_rand)
if not os.path.isdir(outputFolder):
    logging.info(f'Making output dir: {outputFolder}')
    os.mkdir(outputFolder)

for dataset in datasets:
    
    labels_folder = 'data'

    fileName = os.path.join(labels_folder, dataset.upper() + '-PD_Test_Data_IDs_Labels.csv')

    allSessions = pd.read_csv(fileName)
    subject_ids = allSessions['subject_id'].unique()
    logging.info(f'Training data: {subject_ids.shape[0]} unique subjects in {allSessions.shape[0]} sessions')    
    
    if parallel:
        logging.info(f'Parellel processing of {len(seeds)} seeds using {nworkers} workers')
        with Pool(nworkers) as p:
            p.map(SessionScoreSeed, seeds)
    else:
        logging.info(f'Seriel processing of {len(seeds)} seeds')
        for seed in seeds:
            SessionScoreSeed(seed)
# Out:
# INFO: 2020-05-13 19:43:38,676: Making output dir: features/Submit_Final
# INFO: 2020-05-13 19:43:38,679: Training data: 16 unique subjects in 618 sessions
# INFO: 2020-05-13 19:43:38,679: Parellel processing of 12 seeds using 10 workers
# INFO: 2020-05-13 19:43:38,709: Seed 24 Score on_off: Input features_seeds_summary/cis/Submit_Final/on_off_allResults_seed24.csv Output features/BEAT-PD_SC1_on_off_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,709: Seed 21 Score on_off: Input features_seeds_summary/cis/Submit_Final/on_off_allResults_seed21.csv Output features/BEAT-PD_SC1_on_off_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,709: Seed 25 Score on_off: Input features_seeds_summary/cis/Submit_Final/on_off_allResults_seed25.csv Output features/BEAT-PD_SC1_on_off_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,709: Seed 22 Score on_off: Input features_seeds_summary/cis/Submit_Final/on_off_allResults_seed22.csv Output features/BEAT-PD_SC1_on_off_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,710: Seed 27 Score on_off: Input features_seeds_summary/cis/Submit_Final/on_off_allResults_seed27.csv Output features/BEAT-PD_SC1_on_off_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,709: Seed 23 Score on_off: Input features_seeds_summary/cis/Submit_Final/on_off_allResults_seed23.csv Output features/BEAT-PD_SC1_on_off_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,710: Seed 28 Score on_off: Input features_seeds_summary/cis/Submit_Final/on_off_allResults_seed28.csv Output features/BEAT-PD_SC1_on_off_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,710: Seed 29 Score on_off: Input features_seeds_summary/cis/Submit_Final/on_off_allResults_seed29.csv Output features/BEAT-PD_SC1_on_off_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,710: Seed 30 Score on_off: Input features_seeds_summary/cis/Submit_Final/on_off_allResults_seed30.csv Output features/BEAT-PD_SC1_on_off_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,717: Seed 25 Score dyskinesia: Input features_seeds_summary/cis/Submit_Final/dyskinesia_allResults_seed25.csv Output features/BEAT-PD_SC2_dyskinesia_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,717: Seed 23 Score dyskinesia: Input features_seeds_summary/cis/Submit_Final/dyskinesia_allResults_seed23.csv Output features/BEAT-PD_SC2_dyskinesia_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,717: Seed 22 Score dyskinesia: Input features_seeds_summary/cis/Submit_Final/dyskinesia_allResults_seed22.csv Output features/BEAT-PD_SC2_dyskinesia_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,709: Seed 26 Score on_off: Input features_seeds_summary/cis/Submit_Final/on_off_allResults_seed26.csv Output features/BEAT-PD_SC1_on_off_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,717: Seed 27 Score dyskinesia: Input features_seeds_summary/cis/Submit_Final/dyskinesia_allResults_seed27.csv Output features/BEAT-PD_SC2_dyskinesia_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,717: Seed 24 Score dyskinesia: Input features_seeds_summary/cis/Submit_Final/dyskinesia_allResults_seed24.csv Output features/BEAT-PD_SC2_dyskinesia_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,721: Seed 22 Score tremor: Input features_seeds_summary/cis/Submit_Final/tremor_allResults_seed22.csv Output features/BEAT-PD_SC3_tremor_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,721: Seed 23 Score tremor: Input features_seeds_summary/cis/Submit_Final/tremor_allResults_seed23.csv Output features/BEAT-PD_SC3_tremor_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,721: Seed 25 Score tremor: Input features_seeds_summary/cis/Submit_Final/tremor_allResults_seed25.csv Output features/BEAT-PD_SC3_tremor_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,723: Seed 26 Score dyskinesia: Input features_seeds_summary/cis/Submit_Final/dyskinesia_allResults_seed26.csv Output features/BEAT-PD_SC2_dyskinesia_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,720: Seed 28 Score dyskinesia: Input features_seeds_summary/cis/Submit_Final/dyskinesia_allResults_seed28.csv Output features/BEAT-PD_SC2_dyskinesia_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,723: Seed 30 Score dyskinesia: Input features_seeds_summary/cis/Submit_Final/dyskinesia_allResults_seed30.csv Output features/BEAT-PD_SC2_dyskinesia_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,727: Seed 26 Score tremor: Input features_seeds_summary/cis/Submit_Final/tremor_allResults_seed26.csv Output features/BEAT-PD_SC3_tremor_Submit_Final.csv
# INFO: 2020-05-13 19:43:38,728: Seed 24 Score tremor: Input features_seeds_summary/cis/Submit_Final/tremor_allResults_se
# INFO: 2020-05-13 20:05:43,747: Seed 31 Score dyskinesia: Input features_seeds_summary/real/Submit_Final/dyskinesia_allResults_seed31.csv Output features/Submit_Final/BEAT-PD_SC2_dyskinesia_31.csv
# INFO: 2020-05-13 20:05:43,771: Seed 31 Score tremor: Input features_seeds_summary/real/Submit_Final/tremor_allResults_seed31.csv Output features/Submit_Final/BEAT-PD_SC3_tremor_31.csv
# INFO: 2020-05-13 20:05:44,007: Seed 26 Subject hbv043 Score dyskinesia Best method dyskinesia_useWholeS
# INFO: 2020-05-13 20:05:44,030: Save file: BEAT-PD_SC1_on_off_25.csv
# INFO: 2020-05-13 20:05:44,054: Save file: BEAT-PD_SC2_dyskinesia_25.csv
# INFO: 2020-05-13 20:05:44,073: Save file: BEAT-PD_SC3_tremor_25.csv
# INFO: 2020-05-13 20:05:44,091: Seed 32 Score on_off: Input features_seeds_summary/real/Submit_Final/on_off_allResults_seed32.csv Output features/Submit_Final/BEAT-PD_SC1_on_off_32.csv
# INFO: 2020-05-13 20:05:44,119: Seed 32 Score dyskinesia: Input features_seeds_summary/real/Submit_Final/dyskinesia_allResults_seed32.csv Output features/Submit_Final/BEAT-PD_SC2_dyskinesia_32.csv
# INFO: 2020-05-13 20:05:44,147: Seed 32 Score tremor: Input features_seeds_summary/real/Submit_Final/tremor_allResults_seed32.csv Output features/Submit_Final/BEAT-PD_SC3_tremor_32.csv
# INFO: 2020-05-13 20:05:44,593: session not found in pred matrix57c1a938-f334-4f16-a98a-6ea07f3041c9
# INFO: 2020-05-13 20:05:44,606: Seed 29 Subject hbv043 Score dyskinesia Best method dyskinesia_bestCombination
# INFO: 2020-05-13 20:05:44,657: Seed 23 Subject hbv022 Score on_off Best method on_off_RFregressor
# INFO: 2020-05-13 20:05:45,659: Seed 28 Subject hbv043 Score dyskinesia Best method dyskinesia_naive
# INFO: 2020-05-13 20:05:45,736: Seed 32 Subject hbv013 Score on_off Best method on_off_kBest50
# INFO: 2020-05-13 20:05:46,014: Seed 31 Subject hbv013 Score on_off Best method on_off_naive
# INFO: 2020-05-13 20:05:46,086: Seed 22 Subject hbv043 Score on_off Best method on_off_RFregressor
# INFO: 2020-05-13 20:05:48,279: Seed 23 Subject hbv022 Score tremor Best method tremor_rfFeatureSel
# INFO: 2020-05-13 20:05:48,313: Seed 22 Subject hbv043 Score dyskinesia Best method dyskinesia_bestCombination
# INFO: 2020-05-13 20:05:49,708: Seed 29 Subject hbv022 Score on_off Best method on_off_naive
# INFO: 2020-05-13 20:05:49,713: Seed 26 Subject hbv022 Score on_off Best method on_off_kBest50
# INFO: 2020-05-13 20:05:50,163: Seed 28 Subject hbv022 Score on_off Best method on_off_useWholeS
# INFO: 2020-05-13 20:05:50,213: Seed 31 Subject hbv013 Score dyskinesia Best method dyskinesia_rfFeatureSel
# INFO: 2020-05-13 20:05:50,577: Seed 32 Subject hbv013 Score dyskinesia Best method dyskinesia_naive
# INFO: 2020-05-13 20:05:51,393: Seed 22 Subject hbv022 Score on_off Best method on_off_useWholeS
# INFO: 2020-05-13 20:05:52,506: Seed 23 Subject hbv012 Score tremor Best method tremor_undersample
# INFO: 2020-05-13 20:05:53,290: session not found in pred matrixa016c37a-dc8a-4fa6-97b5-8f64c37c7e3e
# INFO: 2020-05-13 20:05:53,472: Seed 26 Subject hbv022 Score tremor Best method tremor_bestCombination
# INFO: 2020-05-13 20:05:53,511: Save file: BEAT-PD_SC1_on_off_23.csv
# INFO: 2020-05-13 20:05:53,539: Save file: BEAT-PD_SC2_dyskinesia_23.csv
# INFO: 2020-05-13 20:05:53,565: Save file: BEAT-PD_SC3_tremor_23.csv
# INFO: 2020-05-13 20:05:53,887: Seed 29 Subject hbv022 Score tremor Best method tremor_bestCombination
# INFO: 2020-05-13 20:05:54,057: Seed 30 Subject hbv018 Score dyskinesia Best method dyskinesia_naive
# INFO: 2020-05-13 20:05:54,926: Seed 32 Subject hbv013 Score tremor Best method tremor_naive
# INFO: 2020-05-13 20:05:55,425: session not found in pred matrix57c1a938-f334-4f16-a98a-6ea07f3041c9
# INFO: 2020-05-13 20:05:55,462: Seed 31 Subject hbv013 Score tremor Best method tremor_useWholeS
# INFO: 2020-05-13 20:05:56,417: Seed 28 Subject hbv022 Score tremor Best method tremor_rfFeatureSel
# INFO: 2020-05-13 20:05:56,462: Seed 30 Subject hbv043 Score on_off Best method on_off_undersample
# INFO: 2020-05-13 20:05:57,166: Seed 22 Subject hbv022 Score tremor Best method tremor_rfFeatureSel
# INFO: 2020-05-13 20:05:57,856: Seed 27 Subject hbv054 Score tremor Best method tremor_undersample
# INFO: 2020-05-13 20:05:58,188: Seed 30 Subject hbv043 Score dyskinesia Best method dyskinesia_naive
# INFO: 2020-05-13 20:05:58,777: Seed 21 Subject hbv012 Score tremor Best method tremor_naive
# INFO: 2020-05-13 20:05:59,222: session not found in pred matrix77c51cd0-fd06-4f71-bbab-105c1398d9eb
# INFO: 2020-05-13 20:05:59,977: Seed 32 Subject hbv038 Score on_off Best method on_off_naive
# INFO: 2020-05-13 20:06:00,357: Save file: BEAT-PD_SC1_on_off_21.csv
# INFO: 2020-05-13 20:06:00,382: Save file: BEAT-PD_SC2_dyskinesia_21.csv
# INFO: 2020-05-13 20:06:00,409: Save file: BEAT-PD_SC3_tremor_21.csv
# INFO: 2020-05-13 20:06:00,833: Seed 28 Subject hbv012 Score tremor Best method tremor_naive
# INFO: 2020-05-13 20:06:01,236: Seed 22 Subject hbv012 Score tremor Best method tremor_RFregressor
# INFO: 2020-05-13 20:06:01,253: Seed 27 Subject hbv014 Score on_off Best method on_off_RFregressor
# INFO: 2020-05-13 20:06:01,653: Seed 32 Subject hbv038 Score tremor Best method tremor_naive
# INFO: 2020-05-13 20:06:01,667: Seed 30 Subject hbv022 Score on_off Best method on_off_RFregressor
# INFO: 2020-05-13 20:06:02,183: Save file: BEAT-PD_SC1_on_off_28.csv
# INFO: 2020-05-13 20:06:02,191: Save file: BEAT-PD_SC2_dyskinesia_28.csv
# INFO: 2020-05-13 20:06:02,206: Save file: BEAT-PD_SC3_tremor_28.csv
# INFO: 2020-05-13 20:06:02,535: session not found in pred matrix77c51cd0-fd06-4f71-bbab-105c1398d9eb
# INFO: 2020-05-13 20:06:02,602: Save file: BEAT-PD_SC1_on_off_22.csv
# INFO: 2020-05-13 20:06:02,607: Save file: BEAT-PD_SC2_dyskinesia_22.csv
# INFO: 2020-05-13 20:06:02,610: Save file: BEAT-PD_SC3_tremor_22.csv
# INFO: 2020-05-13 20:06:03,250: Seed 31 Subject hbv038 Score on_off Best method on_off_RFregressor
# INFO: 2020-05-13 20:06:03,925: session not found in pred matrixa016c37a-dc8a-4fa6-97b5-8f64c37c7e3e
# INFO: 2020-05-13 20:06:04,630: Seed 27 Subject hbv018 Score dyskinesia Best method dyskinesia_naive
# INFO: 2020-05-13 20:06:04,641: Seed 30 Subject hbv022 Score tremor Best method tremor_bestCombination
# INFO: 2020-05-13 20:06:04,712: Seed 31 Subject hbv038 Score tremor Best method tremor_RFregressor
# INFO: 2020-05-13 20:06:04,832: Seed 32 Subject hbv017 Score dyskinesia Best method dyskinesia_rfFeatureSel
# INFO: 2020-05-13 20:06:05,445: Seed 26 Subject hbv012 Score tremor Best method tremor_undersample
# INFO: 2020-05-13 20:06:06,062: session not found in pred matrix57c1a938-f334-4f16-a98a-6ea07f3041c9
# INFO: 2020-05-13 20:06:06,081: Seed 29 Subject hbv012 Score tremor Best method tremor_useWholeS
# INFO: 2020-05-13 20:06:06,105: Save file: BEAT-PD_SC1_on_off_26.csv
# INFO: 2020-05-13 20:06:06,109: Save file: BEAT-PD_SC2_dyskinesia_26.csv
# INFO: 2020-05-13 20:06:06,111: Save file: BEAT-PD_SC3_tremor_26.csv
# INFO: 2020-05-13 20:06:06,905: Seed 27 Subject hbv043 Score on_off Best method on_off_bestCombination
# INFO: 2020-05-13 20:06:07,890: Seed 31 Subject hbv017 Score dyskinesia Best method dyskinesia_bestCombination
# INFO: 2020-05-13 20:06:08,189: Save file: BEAT-PD_SC1_on_off_29.csv
# INFO: 2020-05-13 20:06:08,193: Save file: BEAT-PD_SC2_dyskinesia_29.csv
# INFO: 2020-05-13 20:06:08,195: Save file: BEAT-PD_SC3_tremor_29.csv
# INFO: 2020-05-13 20:06:09,317: Seed 32 Subject hbv023 Score tremor Best method tremor_undersample
# INFO: 2020-05-13 20:06:10,918: Seed 32 Subject hbv051 Score on_off Best method on_off_naive
# INFO: 2020-05-13 20:06:11,396: Seed 27 Subject hbv043 Score dyskinesia Best method dyskinesia_RFregressor
# INFO: 2020-05-13 20:06:13,424: Seed 32 Subject hbv077 Score on_off Best method on_off_RFregressor
# INFO: 2020-05-13 20:06:14,414: Seed 27 Subject hbv022 Score on_off Best method on_off_naive
# INFO: 2020-05-13 20:06:15,114: Seed 30 Subject hbv012 Score tremor Best method tremor_naive
# INFO: 2020-05-13 20:06:16,243: Save file: BEAT-PD_SC1_on_off_30.csv
# INFO: 2020-05-13 20:06:16,247: Save file: BEAT-PD_SC2_dyskinesia_30.csv
# INFO: 2020-05-13 20:06:16,249: Save file: BEAT-PD_SC3_tremor_30.csv
# INFO: 2020-05-13 20:06:16,347: Seed 32 Subject hbv054 Score dyskinesia Best method dyskinesia_RFregressor
# INFO: 2020-05-13 20:06:17,218: Seed 27 Subject hbv022 Score tremor Best method tremor_rfFeatureSel
# INFO: 2020-05-13 20:06:18,998: Seed 32 Subject hbv054 Score tremor Best method tremor_RFregressor
# INFO: 2020-05-13 20:06:20,372: Seed 27 Subject hbv012 Score tremor Best method tremor_RFregressor
# INFO: 2020-05-13 20:06:21,369: Save file: BEAT-PD_SC1_on_off_27.csv
# INFO: 2020-05-13 20:06:21,373: Save file: BEAT-PD_SC2_dyskinesia_27.csv
# INFO: 2020-05-13 20:06:21,375: Save file: BEAT-PD_SC3_tremor_27.csv
# INFO: 2020-05-13 20:06:22,492: Seed 32 Subject hbv014 Score on_off Best method on_off_bestCombination
# INFO: 2020-05-13 20:06:23,643: session not found in pred matrixa016c37a-dc8a-4fa6-97b5-8f64c37c7e3e
# INFO: 2020-05-13 20:06:24,240: Seed 32 Subject hbv018 Score dyskinesia Best method dyskinesia_naive
# INFO: 2020-05-13 20:06:25,419: session not found in pred matrix57c1a938-f334-4f16-a98a-6ea07f3041c9
# INFO: 2020-05-13 20:06:26,170: Seed 32 Subject hbv043 Score on_off Best method on_off_bestCombination
# INFO: 2020-05-13 20:06:27,205: Seed 31 Subject hbv023 Score tremor Best method tremor_undersample
# INFO: 2020-05-13 20:06:28,824: Seed 31 Subject hbv051 Score on_off Best method on_off_bestCombination
# INFO: 2020-05-13 20:06:30,640: Seed 31 Subject hbv077 Score on_off Best method on_off_RFregressor
# INFO: 2020-05-13 20:06:33,597: Seed 31 Subject hbv054 Score dyskinesia Best method dyskinesia_naive
# INFO: 2020-05-13 20:06:34,844: Seed 32 Subject hbv043 Score dyskinesia Best method dyskinesia_naive
# INFO: 2020-05-13 20:06:36,098: Seed 31 Subject hbv054 Score tremor Best method tremor_naive
# INFO: 2020-05-13 20:06:37,636: Seed 32 Subject hbv022 Score on_off Best method on_off_useWholeS
# INFO: 2020-05-13 20:06:39,555: Seed 31 Subject hbv014 Score on_off Best method on_off_bestCombination
# INFO: 2020-05-13 20:06:41,116: session not found in pred matrixa016c37a-dc8a-4fa6-97b5-8f64c37c7e3e
# INFO: 2020-05-13 20:06:41,758: Seed 31 Subject hbv018 Score dyskinesia Best method dyskinesia_naive
# INFO: 2020-05-13 20:06:42,039: Seed 32 Subject hbv022 Score tremor Best method tremor_bestCombination
# INFO: 2020-05-13 20:06:42,925: session not found in pred matrix57c1a938-f334-4f16-a98a-6ea07f3041c9
# INFO: 2020-05-13 20:06:43,692: Seed 31 Subject hbv043 Score on_off Best method on_off_naive
# INFO: 2020-05-13 20:06:45,292: Seed 31 Subject hbv043 Score dyskinesia Best method dyskinesia_RFregressor
# INFO: 2020-05-13 20:06:48,060: Seed 31 Subject hbv022 Score on_off Best method on_off_naive
# INFO: 2020-05-13 20:06:50,488: Seed 31 Subject hbv022 Score tremor Best method tremor_bestCombination
# INFO: 2020-05-13 20:06:56,557: Seed 32 Subject hbv012 Score tremor Best method tremor_undersample
# INFO: 2020-05-13 20:06:57,108: Save file: BEAT-PD_SC1_on_off_32.csv
# INFO: 2020-05-13 20:06:57,110: Save file: BEAT-PD_SC2_dyskinesia_32.csv
# INFO: 2020-05-13 20:06:57,112: Save file: BEAT-PD_SC3_tremor_32.csv
# INFO: 2020-05-13 20:07:00,810: Seed 31 Subject hbv012 Score tremor Best method tremor_naive
# INFO: 2020-05-13 20:07:01,796: Save file: BEAT-PD_SC1_on_off_31.csv
# INFO: 2020-05-13 20:07:01,799: Save file: BEAT-PD_SC2_dyskinesia_31.csv
# INFO: 2020-05-13 20:07:01,801: Save file: BEAT-PD_SC3_tremor_31.csv
